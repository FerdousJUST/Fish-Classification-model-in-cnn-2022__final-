# %% [markdown]
# <a href="https://colab.research.google.com/github/FerdousJUST/Fish-Classification-model-in-cnn-2022__final-/blob/main/Fish_Image_Classification_My_Model02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import imageio
import pathlib
# %matplotlib inline
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import plot_model
import numpy as np
from glob import glob
from tensorflow.keras.layers import Input,Flatten,Dense,BatchNormalization,Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# re-size all the images to this
IMAGE_SIZE = [128,128]

train_path = '/content/drive/Shareddrives/Research Collaboration/Image_Classification_Dataset/Training'
valid_path = '/content/drive/Shareddrives/Research Collaboration/Image_Classification_Dataset/Validation'

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(train_path,
                                                 target_size = (128,128),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')

test_set = test_datagen.flow_from_directory(valid_path,
                                            target_size = (128,128),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 4800 images belonging to 4 classes.
# Found 1200 images belonging to 4 classes.

# %%
model = tf.keras.models.Sequential([tf.keras.layers.Conv2D(16,padding='same', strides=(1, 1),dilation_rate=(1, 1),
                                    kernel_size=(3,3),activation = 'relu',input_shape = (128,128,3)),
                                    tf.keras.layers.MaxPool2D(2,2), 
                                   
                                    
                                    tf.keras.layers.Conv2D(32,padding='same',strides=(1, 1),dilation_rate=(1, 1),
                                    kernel_size=(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                 

                                    tf.keras.layers.Conv2D(64,padding='same',strides=(1, 1),dilation_rate=(1, 1),
                                    kernel_size=(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                   

                                    tf.keras.layers.Conv2D(128,padding='same',strides=(1, 1),dilation_rate=(1, 1),
                                    kernel_size=(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                  

                                    tf.keras.layers.Conv2D(256,padding='same',strides=(1, 1),dilation_rate=(1, 1),
                                    kernel_size=(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                                                                                    
                                    tf.keras.layers.Flatten(),

                                    tf.keras.layers.Dense(512,activation = 'relu'),
                                    tf.keras.layers.Dropout(0.2),                               

                                    tf.keras.layers.Dense(4,activation = 'softmax')
                                    ])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 64, 64, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 32, 32, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 128)       73856
#
#  max_pooling2d_3 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         295168
#
#  max_pooling2d_4 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 512)               2097664
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 2,492,324
# Trainable params: 2,492,324
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model = model,show_shapes = True)

# %%
import tensorflow as tf

from keras.models import load_model

model.save('/content/drive/Shareddrives/Research Collaboration/Ferdous MSc Project/part eight/my_model_02.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
from tensorflow.keras.optimizers import Adam
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(loss = 'categorical_crossentropy',
              optimizer = opt,
              metrics = ['accuracy'])

# %%
from keras.callbacks import EarlyStopping,ModelCheckpoint,ReduceLROnPlateau
import h5py

# %%
erl_stop = EarlyStopping(monitor = 'val_loss',patience = 10,restore_best_weights=True)
mod_chk = ModelCheckpoint(
    filepath='/content/drive/Shareddrives/Research Collaboration/Ferdous MSc Project/part eight/my_model_eight.hdf5',
                          monitor = 'val_loss',save_best_only = True)
lr_rate = ReduceLROnPlateau(monitor = 'val_loss',patience = 10,factor = 0.1)

# %%
hist = model.fit_generator(training_set, shuffle = True, epochs=30, validation_data=test_set,
                           callbacks = [erl_stop,mod_chk,lr_rate],verbose =2
                           )
# Out:
# <ipython-input-12-e4f5b71f7fa0>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(training_set, shuffle = True, epochs=30, validation_data=test_set,
# Epoch 1/30
# 150/150 - 1645s - loss: 1.1034 - accuracy: 0.4638 - val_loss: 1.0227 - val_accuracy: 0.5925 - lr: 1.0000e-04 - 1645s/epoch - 11s/step
# Epoch 2/30
# 150/150 - 52s - loss: 0.7695 - accuracy: 0.6552 - val_loss: 0.8932 - val_accuracy: 0.6158 - lr: 1.0000e-04 - 52s/epoch - 348ms/step
# Epoch 3/30
# 150/150 - 52s - loss: 0.6496 - accuracy: 0.7358 - val_loss: 0.6775 - val_accuracy: 0.7358 - lr: 1.0000e-04 - 52s/epoch - 346ms/step
# Epoch 4/30
# 150/150 - 51s - loss: 0.5262 - accuracy: 0.8000 - val_loss: 0.6380 - val_accuracy: 0.7450 - lr: 1.0000e-04 - 51s/epoch - 342ms/step
# Epoch 5/30
# 150/150 - 53s - loss: 0.4149 - accuracy: 0.8542 - val_loss: 0.3970 - val_accuracy: 0.8375 - lr: 1.0000e-04 - 53s/epoch - 351ms/step
# Epoch 6/30
# 150/150 - 51s - loss: 0.3353 - accuracy: 0.8752 - val_loss: 0.4474 - val_accuracy: 0.8283 - lr: 1.0000e-04 - 51s/epoch - 341ms/step
# Epoch 7/30
# 150/150 - 51s - loss: 0.2868 - accuracy: 0.8952 - val_loss: 0.3763 - val_accuracy: 0.8592 - lr: 1.0000e-04 - 51s/epoch - 343ms/step
# Epoch 8/30
# 150/150 - 51s - loss: 0.2597 - accuracy: 0.8988 - val_loss: 0.4191 - val_accuracy: 0.8342 - lr: 1.0000e-04 - 51s/epoch - 340ms/step
# Epoch 9/30
# 150/150 - 52s - loss: 0.2265 - accuracy: 0.9112 - val_loss: 0.2926 - val_accuracy: 0.8950 - lr: 1.0000e-04 - 52s/epoch - 347ms/step
# Epoch 10/30
# 150/150 - 51s - loss: 0.2005 - accuracy: 0.9223 - val_loss: 0.3771 - val_accuracy: 0.8633 - lr: 1.0000e-04 - 51s/epoch - 341ms/step
# Epoch 11/30
# 150/150 - 52s - loss: 0.1791 - accuracy: 0.9315 - val_loss: 0.2526 - val_accuracy: 0.9092 - lr: 1.0000e-04 - 52s/epoch - 345ms/step
# Epoch 12/30
# 150/150 - 52s - loss: 0.1734 - accuracy: 0.9319 - val_loss: 0.2077 - val_accuracy: 0.9308 - lr: 1.0000e-04 - 52s/epoch - 347ms/step
# Epoch 13/30
# 150/150 - 52s - loss: 0.1657 - accuracy: 0.9377 - val_loss: 0.2920 - val_accuracy: 0.8925 - lr: 1.0000e-04 - 52s/epoch - 344ms/step
# Epoch 14/30
# 150/150 - 54s - loss: 0.1487 - accuracy: 0.9431 - val_loss: 0.2682 - val_accuracy: 0.9042 - lr: 1.0000e-04 - 54s/epoch - 357ms/step
# Epoch 15/30
# 150/150 - 53s - loss: 0.1353 - accuracy: 0.9492 - val_loss: 0.3314 - val_accuracy: 0.8617 - lr: 1.0000e-04 - 53s/epoch - 354ms/step
# Epoch 16/30
# 150/150 - 51s - loss: 0.1241 - accuracy: 0.9579 - val_loss: 0.1810 - val_accuracy: 0.9342 - lr: 1.0000e-04 - 51s/epoch - 343ms/step
# Epoch 17/30
# 150/150 - 54s - loss: 0.1177 - accuracy: 0.9533 - val_loss: 0.2156 - val_accuracy: 0.9125 - lr: 1.0000e-04 - 54s/epoch - 360ms/step
# Epoch 18/30
# 150/150 - 54s - loss: 0.1079 - accuracy: 0.9575 - val_loss: 0.3145 - val_accuracy: 0.8692 - lr: 1.0000e-04 - 54s/epoch - 363ms/step
# Epoch 19/30
# 150/150 - 55s - loss: 0.1139 - accuracy: 0.9554 - val_loss: 0.2574 - val_accuracy: 0.8908 - lr: 1.0000e-04 - 55s/epoch - 369ms/step
# Epoch 20/30
# 150/150 - 55s - loss: 0.0919 - accuracy: 0.9650 - val_loss: 0.2241 - val_accuracy: 0.9058 - lr: 1.0000e-04 - 55s/epoch - 364ms/step
# Epoch 21/30
# 150/150 - 55s - loss: 0.1009 - accuracy: 0.9594 - val_loss: 0.1241 - val_accuracy: 0.9517 - lr: 1.0000e-04 - 55s/epoch - 364ms/step
# Epoch 22/30
# 150/150 - 55s - loss: 0.0812 - accuracy: 0.9710 - val_loss: 0.1217 - val_accuracy: 0.9600 - lr: 1.0000e-04 - 55s/epoch - 364ms/step
# Epoch 23/30
# 150/150 - 53s - loss: 0.0904 - accuracy: 0.9660 - val_loss: 0.1198 - val_accuracy: 0.9625 - lr: 1.0000e-04 - 53s/epoch - 356ms/step
# Epoch 24/30
# 150/150 - 55s - loss: 0.0773 - accuracy: 0.9706 - val_loss: 0.1463 - val_accuracy: 0.9417 - lr: 1.0000e-04 - 55s/epoch - 367ms/step
# Epoch 25/30
# 150/150 - 55s - loss: 0.0800 - accuracy: 0.9694 - val_loss: 0.1370 - val_accuracy: 0.9558 - lr: 1.0000e-04 - 55s/epoch - 367ms/step
# Epoch 26/30
# 150/150 - 55s - loss: 0.0711 - accuracy: 0.9746 - val_loss: 0.1674 - val_accuracy: 0.9392 - lr: 1.0000e-04 - 55s/epoch - 364ms/step
# Epoch 27/30
# 150/150 - 54s - loss: 0.0639 - accuracy: 0.9758 - val_loss: 0.2096 - val_accuracy: 0.9308 - lr: 1.0000e-04 - 54s/epoch - 363ms/step
# Epoch 28/30
# 150/150 - 56s - loss: 0.0708 - accuracy: 0.9715 - val_loss: 0.0925 - val_accuracy: 0.9742 - lr: 1.0000e-04 - 56s/epoch - 374ms/step
# Epoch 29/30
# 150/150 - 55s - loss: 0.0570 - accuracy: 0.9794 - val_loss: 0.1260 - val_accuracy: 0.9675 - lr: 1.0000e-04 - 55s/epoch - 366ms/step
# Epoch 30/30
# 150/150 - 52s - loss: 0.0610 - accuracy: 0.9792 - val_loss: 0.0940 - val_accuracy: 0.9658 - lr: 1.0000e-04 - 52s/epoch - 349ms/step

# %%
acc = model.evaluate(test_set,steps = len(test_set),verbose = 2)
print('%.2f'%(acc[1]*100))
# Out:
# 38/38 - 9s - loss: 0.0940 - accuracy: 0.9658 - 9s/epoch - 245ms/step
# 96.58

# %%
plt.figure(figsize = (8,6))
plt.plot(hist.history['loss'],'b-o',color = 'blue',label = 'train',linewidth=3.0)
plt.plot(hist.history['val_loss'],'b-o',color = 'orange',label = 'train',linewidth=3.0)
plt.grid(True)
epochs = range(1,30)
plt.legend(['Train Loss', 'Test Val_Loss'], loc='upper right')
plt.title("Train & Test Loss with Epochs\n",fontsize = 16)
plt.xlabel("Training Epochs",fontsize= 16)
plt.ylabel("Train & Test Loss",fontsize =16)
plt.show()

# %%
plt.figure(figsize = (8,6))
plt.plot(hist.history['accuracy'],'b-o',color = 'blue',label = 'train',linewidth=3.0)
plt.plot(hist.history['val_accuracy'],'b-o',color = 'orange',label = 'train',linewidth=3.0)
plt.grid(True)
epochs = range(1,30)
#plt.legend(['loss', 'val_loss'], loc='upper right')
plt.legend(['Train Accuracy', 'Test Accuracy'], loc='lower right')
plt.title("Train & Test Accuracy with Epochs\n",fontsize = 16)
plt.xlabel("Training Epochs",fontsize= 16)
plt.ylabel("Train & Test Accuracy",fontsize =16)
plt.show()

# %%
from tensorflow.python.ops.gen_math_ops import Round
from keras.preprocessing import image
import numpy as np
from keras.utils import load_img, img_to_array
test_image = load_img(
'/content/drive/Shareddrives/Research Collaboration/Image_Classification_Dataset/Training/Tilapia_Fish/Tilapia_Fish 004.png', 
                      target_size = (128,128))
test_image = img_to_array(test_image)
test_image = np.expand_dims(test_image,axis = 0)
rslt = model.predict(test_image)
print (rslt)


list_index = [0,1,2,3]

x = rslt

for i in range(4):
  for j in range(4):
    if x[0][list_index[i]] > x[0][list_index[j]]:
          temp = list_index[i]
          list_index[i] = list_index[j]
          list_index[j] = temp

print(list_index)

classification = ['Barbel_Fish','Hilsha_Fish','Spotted_Snakehead_Fish','Tilapia_Fish']
     

for i in range(4):
  print(classification[list_index[i]], ':', round(rslt[0][list_index[i]] * 100,2),'%')
# Out:
# 1/1 [==============================] - 0s 234ms/step
# [[0. 0. 0. 1.]]
# [3, 1, 2, 0]
# Tilapia_Fish : 100.0 %
# Hilsha_Fish : 0.0 %
# Spotted_Snakehead_Fish : 0.0 %
# Barbel_Fish : 0.0 %

# %%
from tensorflow.python.ops.gen_math_ops import Round
from keras.preprocessing import image
import numpy as np
from keras.utils import load_img, img_to_array
test_image = load_img(
'/content/drive/Shareddrives/Research Collaboration/Image_Classification_Dataset/Training/Barbel_Fish/Barbel_Fish 006.jpg', 
                      target_size = (128,128))
test_image = img_to_array(test_image)
test_image = np.expand_dims(test_image,axis = 0)
rslt = model.predict(test_image)
print (rslt)


list_index = [0,1,2,3]

x = rslt

for i in range(4):
  for j in range(4):
    if x[0][list_index[i]] > x[0][list_index[j]]:
          temp = list_index[i]
          list_index[i] = list_index[j]
          list_index[j] = temp

print(list_index)

classification = ['Barbel_Fish','Hilsha_Fish','Spotted_Snakehead_Fish','Tilapia_Fish']
     

for i in range(4):
  print(classification[list_index[i]], ':', round(rslt[0][list_index[i]] * 100,2),'%')
# Out:
# 1/1 [==============================] - 0s 17ms/step
# [[1. 0. 0. 0.]]
# [0, 1, 2, 3]
# Barbel_Fish : 100.0 %
# Hilsha_Fish : 0.0 %
# Spotted_Snakehead_Fish : 0.0 %
# Tilapia_Fish : 0.0 %

# %%
from tensorflow.python.ops.gen_math_ops import Round
from keras.preprocessing import image
import numpy as np
from keras.utils import load_img, img_to_array
test_image = load_img(
'/content/drive/Shareddrives/Research Collaboration/Image_Classification_Dataset/Validation/Spotted_Snakehead_Fish/Spotted_Fish 015.jpg', 
                      target_size = (128,128))
test_image = img_to_array(test_image)
test_image = np.expand_dims(test_image,axis = 0)
rslt = model.predict(test_image)
print (rslt)


list_index = [0,1,2,3]

x = rslt

for i in range(4):
  for j in range(4):
    if x[0][list_index[i]] > x[0][list_index[j]]:
          temp = list_index[i]
          list_index[i] = list_index[j]
          list_index[j] = temp

print(list_index)

classification = ['Barbel_Fish','Hilsha_Fish','Spotted_Snakehead_Fish','Tilapia_Fish']
     

for i in range(4):
  print(classification[list_index[i]], ':', round(rslt[0][list_index[i]] * 100,2),'%')
# Out:
# 1/1 [==============================] - 0s 17ms/step
# [[1. 0. 0. 0.]]
# [0, 1, 2, 3]
# Barbel_Fish : 100.0 %
# Hilsha_Fish : 0.0 %
# Spotted_Snakehead_Fish : 0.0 %
# Tilapia_Fish : 0.0 %

# %%
from tensorflow.python.ops.gen_math_ops import Round
from keras.preprocessing import image
import numpy as np
from keras.utils import load_img, img_to_array
test_image = load_img(
'/content/drive/Shareddrives/Research Collaboration/Image_Classification_Dataset/Training/Hilsha_Fish/Hilsha_Fish 049.jpg', 
                      target_size = (128,128))
test_image = img_to_array(test_image)
test_image = np.expand_dims(test_image,axis = 0)
rslt = model.predict(test_image)
print (rslt)


list_index = [0,1,2,3]

x = rslt

for i in range(4):
  for j in range(4):
    if x[0][list_index[i]] > x[0][list_index[j]]:
          temp = list_index[i]
          list_index[i] = list_index[j]
          list_index[j] = temp

print(list_index)

classification = ['Barbel_Fish','Hilsha_Fish','Spotted_Snakehead_Fish','Tilapia_Fish']
     

for i in range(4):
  print(classification[list_index[i]], ':', round(rslt[0][list_index[i]] * 100,2),'%')
# Out:
# 1/1 [==============================] - 0s 25ms/step
# [[0. 1. 0. 0.]]
# [1, 0, 2, 3]
# Hilsha_Fish : 100.0 %
# Barbel_Fish : 0.0 %
# Spotted_Snakehead_Fish : 0.0 %
# Tilapia_Fish : 0.0 %

# %%
from tensorflow.python.ops.gen_math_ops import Round
from keras.preprocessing import image
import numpy as np
from keras.utils import load_img, img_to_array
test_image = load_img(
'/content/hilsha3.jpg', 
                      target_size = (128,128))
test_image = img_to_array(test_image)
test_image = np.expand_dims(test_image,axis = 0)
rslt = model.predict(test_image)
print (rslt)


list_index = [0,1,2,3]

x = rslt

for i in range(4):
  for j in range(4):
    if x[0][list_index[i]] > x[0][list_index[j]]:
          temp = list_index[i]
          list_index[i] = list_index[j]
          list_index[j] = temp

print(list_index)

classification = ['Barbel_Fish','Hilsha_Fish','Spotted_Snakehead_Fish','Tilapia_Fish']
     

for i in range(4):
  print(classification[list_index[i]], ':', round(rslt[0][list_index[i]] * 100,2),'%')
# Out:
# 1/1 [==============================] - 0s 17ms/step
# [[0. 1. 0. 0.]]
# [1, 0, 2, 3]
# Hilsha_Fish : 100.0 %
# Barbel_Fish : 0.0 %
# Spotted_Snakehead_Fish : 0.0 %
# Tilapia_Fish : 0.0 %

# %%
from tensorflow.python.ops.gen_math_ops import Round
from keras.preprocessing import image
import numpy as np
from keras.utils import load_img, img_to_array
test_image = load_img(
'/content/drive/Shareddrives/Research Collaboration/Image_Classification_Dataset/Validation/Spotted_Snakehead_Fish/Spotted_Fish 052.jpg', 
                      target_size = (128,128))
test_image = img_to_array(test_image)
test_image = np.expand_dims(test_image,axis = 0)
rslt = model.predict(test_image)
print (rslt)


list_index = [0,1,2,3]

x = rslt

for i in range(4):
  for j in range(4):
    if x[0][list_index[i]] > x[0][list_index[j]]:
          temp = list_index[i]
          list_index[i] = list_index[j]
          list_index[j] = temp

print(list_index)

classification = ['Barbel_Fish','Hilsha_Fish','Spotted_Snakehead_Fish','Tilapia_Fish']
     

for i in range(4):
  print(classification[list_index[i]], ':', round(rslt[0][list_index[i]] * 100,2),'%')
# Out:
# 1/1 [==============================] - 0s 21ms/step
# [[0. 0. 1. 0.]]
# [2, 1, 0, 3]
# Spotted_Snakehead_Fish : 100.0 %
# Hilsha_Fish : 0.0 %
# Barbel_Fish : 0.0 %
# Tilapia_Fish : 0.0 %

# %%
y_pred = model.predict(test_set)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e3c5f7c271de> in <module>
# ----> 1 y_pred = model.predict(test_set)
#
# NameError: name 'model' is not defined

# %%
y_pred = np.argmax(y_pred,axis = 1)

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, recall_score, precision_score, f1_score

print(classification_report(test_set,y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-0cc8e8d6371d> in <module>
#       1 from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, recall_score, precision_score, f1_score
#       2
# ----> 3 print(classification_report(test_set,y_pred))
#
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2108     """
#    2109
# -> 2110     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2111
#    2112     if labels is None:
#
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true)
#      86     type_pred = type_of_target(y_pred)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
# --> 332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
#     334             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [38, 1200]
